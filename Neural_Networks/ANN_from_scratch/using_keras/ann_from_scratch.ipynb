# %%
import pandas as pd
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import RMSprop, Adadelta, Adam
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
# %tensorflow_version 1.x

dig = load_digits()
onehot_target = pd.get_dummies(dig.target)
x_train, x_val, y_train, y_val = train_test_split(dig.data, onehot_target, test_size=0.1, random_state=20)

model = Sequential()
model.add(Dense(128, input_dim=x_train.shape[1], activation='sigmoid'))
model.add(Dense(128, activation='sigmoid'))
model.add(Dense(10, activation='softmax'))

model.summary()

model.compile(optimizer=Adadelta(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
model.fit(x_train, y_train, epochs=50, batch_size=64)

scores = model.evaluate(x_val, y_val)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 26,122
# Trainable params: 26,122
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1617/1617 [==============================] - 0s 225us/step - loss: 2.0713 - categorical_accuracy: 0.4224
# Epoch 2/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 1.4133 - categorical_accuracy: 0.8194
# Epoch 3/50
# 1617/1617 [==============================] - 0s 30us/step - loss: 0.9127 - categorical_accuracy: 0.8980
# Epoch 4/50
# 1617/1617 [==============================] - 0s 33us/step - loss: 0.6185 - categorical_accuracy: 0.9307
# Epoch 5/50
# 1617/1617 [==============================] - 0s 31us/step - loss: 0.4471 - categorical_accuracy: 0.9481
# Epoch 6/50
# 1617/1617 [==============================] - 0s 31us/step - loss: 0.3400 - categorical_accuracy: 0.9561
# Epoch 7/50
# 1617/1617 [==============================] - 0s 29us/step - loss: 0.2711 - categorical_accuracy: 0.9678
# Epoch 8/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.2220 - categorical_accuracy: 0.9734
# Epoch 9/50
# 1617/1617 [==============================] - 0s 32us/step - loss: 0.1845 - categorical_accuracy: 0.9765
# Epoch 10/50
# 1617/1617 [==============================] - 0s 31us/step - loss: 0.1575 - categorical_accuracy: 0.9784
# Epoch 11/50
# 1617/1617 [==============================] - 0s 30us/step - loss: 0.1373 - categorical_accuracy: 0.9827
# Epoch 12/50
# 1617/1617 [==============================] - 0s 29us/step - loss: 0.1183 - categorical_accuracy: 0.9833
# Epoch 13/50
# 1617/1617 [==============================] - 0s 32us/step - loss: 0.1041 - categorical_accuracy: 0.9870
# Epoch 14/50
# 1617/1617 [==============================] - 0s 31us/step - loss: 0.0930 - categorical_accuracy: 0.9864
# Epoch 15/50
# 1617/1617 [==============================] - 0s 32us/step - loss: 0.0817 - categorical_accuracy: 0.9882
# Epoch 16/50
# 1617/1617 [==============================] - 0s 30us/step - loss: 0.0740 - categorical_accuracy: 0.9882
# Epoch 17/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.0671 - categorical_accuracy: 0.9882
# Epoch 18/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.0602 - categorical_accuracy: 0.9913
# Epoch 19/50
# 1617/1617 [==============================] - 0s 34us/step - loss: 0.0541 - categorical_accuracy: 0.9938
# Epoch 20/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.0509 - categorical_accuracy: 0.9926
# Epoch 21/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.0466 - categorical_accuracy: 0.9944
# Epoch 22/50
# 1617/1617 [==============================] - 0s 29us/step - loss: 0.0421 - categorical_accuracy: 0.9938
# Epoch 23/50
# 1617/1617 [==============================] - 0s 34us/step - loss: 0.0391 - categorical_accuracy: 0.9944
# Epoch 24/50
# 1617/1617 [==============================] - 0s 34us/step - loss: 0.0354 - categorical_accuracy: 0.9957
# Epoch 25/50
# 1617/1617 [==============================] - 0s 33us/step - loss: 0.0322 - categorical_accuracy: 0.9969
# Epoch 26/50
# 1617/1617 [==============================] - 0s 31us/step - loss: 0.0301 - categorical_accuracy: 0.9969
# Epoch 27/50
# 1617/1617 [==============================] - 0s 32us/step - loss: 0.0278 - categorical_accuracy: 0.9969
# Epoch 28/50
# 1617/1617 [==============================] - 0s 29us/step - loss: 0.0259 - categorical_accuracy: 0.9981
# Epoch 29/50
# 1617/1617 [==============================] - 0s 30us/step - loss: 0.0243 - categorical_accuracy: 0.9981
# Epoch 30/50
# 1617/1617 [==============================] - 0s 32us/step - loss: 0.0231 - categorical_accuracy: 0.9975
# Epoch 31/50
# 1617/1617 [==============================] - 0s 29us/step - loss: 0.0209 - categorical_accuracy: 0.9981
# Epoch 32/50
# 1617/1617 [==============================] - 0s 37us/step - loss: 0.0195 - categorical_accuracy: 0.9981
# Epoch 33/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.0179 - categorical_accuracy: 0.9981
# Epoch 34/50
# 1617/1617 [==============================] - 0s 30us/step - loss: 0.0166 - categorical_accuracy: 0.9988
# Epoch 35/50
# 1617/1617 [==============================] - 0s 31us/step - loss: 0.0157 - categorical_accuracy: 0.9981
# Epoch 36/50
# 1617/1617 [==============================] - 0s 29us/step - loss: 0.0143 - categorical_accuracy: 0.9988
# Epoch 37/50
# 1617/1617 [==============================] - 0s 29us/step - loss: 0.0141 - categorical_accuracy: 0.9988
# Epoch 38/50
# 1617/1617 [==============================] - 0s 30us/step - loss: 0.0127 - categorical_accuracy: 0.9988
# Epoch 39/50
# 1617/1617 [==============================] - 0s 30us/step - loss: 0.0121 - categorical_accuracy: 0.9988
# Epoch 40/50
# 1617/1617 [==============================] - 0s 30us/step - loss: 0.0109 - categorical_accuracy: 0.9988
# Epoch 41/50
# 1617/1617 [==============================] - 0s 32us/step - loss: 0.0103 - categorical_accuracy: 1.0000
# Epoch 42/50
# 1617/1617 [==============================] - 0s 30us/step - loss: 0.0099 - categorical_accuracy: 0.9994
# Epoch 43/50
# 1617/1617 [==============================] - 0s 30us/step - loss: 0.0093 - categorical_accuracy: 1.0000
# Epoch 44/50
# 1617/1617 [==============================] - 0s 30us/step - loss: 0.0088 - categorical_accuracy: 0.9988
# Epoch 45/50
# 1617/1617 [==============================] - 0s 29us/step - loss: 0.0081 - categorical_accuracy: 1.0000
# Epoch 46/50
# 1617/1617 [==============================] - 0s 31us/step - loss: 0.0080 - categorical_accuracy: 1.0000
# Epoch 47/50
# 1617/1617 [==============================] - 0s 29us/step - loss: 0.0072 - categorical_accuracy: 1.0000
# Epoch 48/50
# 1617/1617 [==============================] - 0s 29us/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 49/50
# 1617/1617 [==============================] - 0s 29us/step - loss: 0.0064 - categorical_accuracy: 1.0000
# Epoch 50/50
# 1617/1617 [==============================] - 0s 30us/step - loss: 0.0061 - categorical_accuracy: 1.0000
# 180/180 [==============================] - 0s 587us/step
#
# categorical_accuracy: 96.67%
